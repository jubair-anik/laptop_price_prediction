# %% [markdown]
# ## About data
#
#
# 1 Company- String -Laptop Manufacturer
#
# 2 Product -String -Brand and Model
#
# 3 TypeName -String -Type (Notebook, Ultrabook, Gaming, etc.)
#
# 4 Inches -Numeric- Screen Size
#
# 5 ScreenResolution -String- Screen Resolution
#
# 6 Cpu- String -Central Processing Unit (CPU)
#
# 7 Ram -String- Laptop RAM
#
# 8 Memory -String- Hard Disk / SSD Memory
#
# 9 GPU -String- Graphics Processing Units (GPU)
#
# 10 OpSys -String- Operating System
#
# 11 Weight -String- Laptop Weight
#
# 12 Price_euros -Numeric- Price (Euro)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('laptop_price.csv',encoding = "ISO-8859-1")
data.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df=data.copy()
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
# let's drop laptop_ID and laptop name 
df.drop(['laptop_ID','Product'],axis = 1,inplace = True)
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94
# ...

# %%
df.shape
# Out:
# (1303, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price_euros       1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
df.duplicated().sum()
# Out:
# 29

# %%
df[df.duplicated( )]
# Out:
#      Company            TypeName  Inches  \
# 1274    Asus            Notebook    15.6
# 1275    Asus           Ultrabook    13.3
# 1276    Dell            Notebook    15.6
# 1277    Acer            Notebook    15.6
# 1278    Dell            Notebook    15.6
# 1279  Lenovo            Notebook    15.6
# 1280      HP            Notebook    15.6
# 1281    Dell            Notebook    15.6
# 1282      HP             Netbook    11.6
# 1283    Asus            Notebook    15.6
# 1284  Lenovo  2 in 1 Convertible    14.0
# 1285  Lenovo  2 in 1 Convertible    13.3
# 1286  Lenovo            Notebook    14.0
# 1287      HP            Notebook    15.6
# 1288    Asus            Notebook    15.6
# 1289    Asus           Ultrabook    13.3
# 1290    Dell            Notebook    15.6
# 1291    Acer            Notebook    15.6
# 1292    Dell            Notebook    15.6
# 1293  Lenovo            Notebook    15.6
# 1294      HP            Notebook    15.6
# 1295    Dell            Notebook    15.6
# ...

# %%
df[df.duplicated(keep = False)]
# Out:
#      Company            TypeName  Inches  \
# 1172    Asus            Notebook    15.6
# 1261    Asus           Ultrabook    13.3
# 1262    Dell            Notebook    15.6
# 1263    Acer            Notebook    15.6
# 1264    Dell            Notebook    15.6
# 1265  Lenovo            Notebook    15.6
# 1266      HP            Notebook    15.6
# 1267    Dell            Notebook    15.6
# 1268      HP             Netbook    11.6
# 1269    Asus            Notebook    15.6
# 1270  Lenovo  2 in 1 Convertible    14.0
# 1271  Lenovo  2 in 1 Convertible    13.3
# 1272  Lenovo            Notebook    14.0
# 1273      HP            Notebook    15.6
# 1274    Asus            Notebook    15.6
# 1275    Asus           Ultrabook    13.3
# 1276    Dell            Notebook    15.6
# 1277    Acer            Notebook    15.6
# 1278    Dell            Notebook    15.6
# 1279  Lenovo            Notebook    15.6
# 1280      HP            Notebook    15.6
# 1281    Dell            Notebook    15.6
# ...

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (1274, 11)

# %% [markdown]
# # Preprocessing

# %%
df['Ram_GB']=df['Ram'].str.replace("GB","")
df['Ram_GB']=df['Ram_GB'].astype('int32')
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros  Ram_GB
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69       8
# 1        Intel HD Graphics 6000  macOS  1.34kg       898.94       8
# ...

# %%
df['Weight_kg']=df['Weight'].str.replace("kg","")
df['Weight_kg']=df['Weight_kg'].astype('float32')
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros  Ram_GB  Weight_kg
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69       8       1.37
# ...

# %%
df.drop(['Ram',"Weight"],axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1274 entries, 0 to 1273
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Memory            1274 non-null   object
#  6   Gpu               1274 non-null   object
#  7   OpSys             1274 non-null   object
#  8   Price_euros       1274 non-null   float64
#  9   Ram_GB            1274 non-null   int32
#  10  Weight_kg         1274 non-null   float32
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 109.5+ KB

# %%
plt.figure(figsize=(16,6))
sns.countplot(df['Company'])
plt.xticks(rotation=60);
# Out:
# E:\bul_reg\ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.distplot(df['Price_euros'])
# Out:
# E:\bul_reg\ml\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price_euros', ylabel='Density'>

# %%
plt.figure(figsize=(16,6))
sns.barplot(x=df['Company'],y=df['Price_euros'])
plt.xticks(rotation = 60)
plt.title("Price of laptop by Brand",fontsize = 20);

# %%
plt.figure(figsize=(12,6))
sns.countplot(df['TypeName'])
plt.xticks(rotation=60);
# Out:
# E:\bul_reg\ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(16,6))
sns.barplot(x=df['TypeName'],y=df['Price_euros'])
plt.xticks(rotation = 60)
plt.title("Price of laptop by type",fontsize = 20);

# %%
sns.distplot(df['Inches']);
# Out:
# E:\bul_reg\ml\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.scatterplot(df['Inches'],df['Price_euros']);
# Out:
# E:\bul_reg\ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=df['Inches'],y=df['Price_euros']);

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                505
# 1366x768                                         262
# IPS Panel Full HD 1920x1080                      226
# IPS Panel Full HD / Touchscreen 1920x1080         51
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# ...

# %% [markdown]
# ## create new column "Touch_screen"
# - 1 = Touch_screen "yes"
# - 2 = Touch_screen "no"

# %%
df['Touch_screen']=df['ScreenResolution'].apply(lambda x:1 if "Touchscreen" in x else 0)
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu               Memory  \
# 0        Intel Core i5 2.3GHz            128GB SSD
# 1        Intel Core i5 1.8GHz  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz            256GB SSD
# 3        Intel Core i7 2.7GHz            512GB SSD
# 4        Intel Core i5 3.1GHz            256GB SSD
#
#                             Gpu  OpSys  Price_euros  Ram_GB  Weight_kg  \
# 0  Intel Iris Plus Graphics 640  macOS      1339.69       8       1.37
# 1        Intel HD Graphics 6000  macOS       898.94       8       1.34
# ...

# %%
df.tail()
# Out:
#      Company            TypeName  Inches  \
# 1269    Asus            Notebook    15.6
# 1270  Lenovo  2 in 1 Convertible    14.0
# 1271  Lenovo  2 in 1 Convertible    13.3
# 1272  Lenovo            Notebook    14.0
# 1273      HP            Notebook    15.6
#
#                                 ScreenResolution  \
# 1269                                    1366x768
# 1270   IPS Panel Full HD / Touchscreen 1920x1080
# 1271  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1272                                    1366x768
# 1273                                    1366x768
#
#                                        Cpu              Memory  \
# 1269            Intel Core i7 6500U 2.5GHz           500GB HDD
# 1270            Intel Core i7 6500U 2.5GHz           128GB SSD
# 1271            Intel Core i7 6500U 2.5GHz           512GB SSD
# 1272  Intel Celeron Dual Core N3050 1.6GHz  64GB Flash Storage
# 1273            Intel Core i7 6500U 2.5GHz             1TB HDD
#
# ...

# %%
sns.countplot(df['Touch_screen']);
# Out:
# E:\bul_reg\ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.barplot(x=df['Touch_screen'],y=df['Price_euros']);

# %% [markdown]
# ## create new column "IPS"
# - 1 = IPS "yes"
# - 2 = IPS "no"

# %%
df['IPS']=df['ScreenResolution'].apply(lambda x:1 if "IPS" in x else 0)
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu               Memory  \
# 0        Intel Core i5 2.3GHz            128GB SSD
# 1        Intel Core i5 1.8GHz  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz            256GB SSD
# 3        Intel Core i7 2.7GHz            512GB SSD
# 4        Intel Core i5 3.1GHz            256GB SSD
#
#                             Gpu  OpSys  Price_euros  Ram_GB  Weight_kg  \
# 0  Intel Iris Plus Graphics 640  macOS      1339.69       8       1.37
# 1        Intel HD Graphics 6000  macOS       898.94       8       1.34
# ...

# %%
sns.countplot(df['IPS']);
# Out:
# E:\bul_reg\ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.barplot(x=df['Touch_screen'],y=df['Price_euros']);

# %%
temp1=df['ScreenResolution'].str.split("x",expand=True)
temp1
# Out:
#                                           0     1
# 0             IPS Panel Retina Display 2560  1600
# 1                                      1440   900
# 2                              Full HD 1920  1080
# 3             IPS Panel Retina Display 2880  1800
# 4             IPS Panel Retina Display 2560  1600
# ...                                     ...   ...
# 1269                                   1366   768
# 1270   IPS Panel Full HD / Touchscreen 1920  1080
# 1271  IPS Panel Quad HD+ / Touchscreen 3200  1800
# 1272                                   1366   768
# 1273                                   1366   768
#
# [1274 rows x 2 columns]

# %%
df["y_resolution"]=temp1[1]
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu               Memory  \
# 0        Intel Core i5 2.3GHz            128GB SSD
# 1        Intel Core i5 1.8GHz  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz            256GB SSD
# 3        Intel Core i7 2.7GHz            512GB SSD
# 4        Intel Core i5 3.1GHz            256GB SSD
#
#                             Gpu  OpSys  Price_euros  Ram_GB  Weight_kg  \
# 0  Intel Iris Plus Graphics 640  macOS      1339.69       8       1.37
# 1        Intel HD Graphics 6000  macOS       898.94       8       1.34
# ...

# %%
# create function to extract number
def num_extract(x):
    import re
    ans = re.findall(r'[0-9]+',x)[0]
    return ans

# %%
df['x_resolution'] = temp1[0].apply(num_extract)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu               Memory  \
# 0        Intel Core i5 2.3GHz            128GB SSD
# 1        Intel Core i5 1.8GHz  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz            256GB SSD
# 3        Intel Core i7 2.7GHz            512GB SSD
# 4        Intel Core i5 3.1GHz            256GB SSD
#
#                             Gpu  OpSys  Price_euros  Ram_GB  Weight_kg  \
# 0  Intel Iris Plus Graphics 640  macOS      1339.69       8       1.37
# 1        Intel HD Graphics 6000  macOS       898.94       8       1.34
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1274 entries, 0 to 1273
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Memory            1274 non-null   object
#  6   Gpu               1274 non-null   object
#  7   OpSys             1274 non-null   object
#  8   Price_euros       1274 non-null   float64
#  9   Ram_GB            1274 non-null   int32
#  10  Weight_kg         1274 non-null   float32
#  11  Touch_screen      1274 non-null   int64
#  12  IPS               1274 non-null   int64
#  13  y_resolution      1274 non-null   object
#  14  x_resolution      1274 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(2), object(9)
# ...

# %%
df["x_resolution"]=df["x_resolution"].astype('int32')
df["y_resolution"]=df["y_resolution"].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1274 entries, 0 to 1273
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Memory            1274 non-null   object
#  6   Gpu               1274 non-null   object
#  7   OpSys             1274 non-null   object
#  8   Price_euros       1274 non-null   float64
#  9   Ram_GB            1274 non-null   int32
#  10  Weight_kg         1274 non-null   float32
#  11  Touch_screen      1274 non-null   int64
#  12  IPS               1274 non-null   int64
#  13  y_resolution      1274 non-null   int32
#  14  x_resolution      1274 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# ...

# %%
df.corr()['Price_euros']
# Out:
# Inches          0.066990
# Price_euros     1.000000
# Ram_GB          0.740106
# Weight_kg       0.212192
# Touch_screen    0.188631
# IPS             0.250358
# y_resolution    0.548111
# x_resolution    0.072208
# Name: Price_euros, dtype: float64

# %%
df['y_resolution'].value_counts()
# Out:
# 1080    833
# 768     289
# 2160     43
# 1440     31
# 1800     29
# 900      27
# 1600     10
# 1504      6
# 1200      5
# 1824      1
# Name: y_resolution, dtype: int64

# %%
# create new feature "PPI"
df['PPI'] = (((df['x_resolution']**2) + (df['y_resolution']**2))**0.5/df['Inches']).astype('float32')

# %%
df.corr()['Price_euros']
# Out:
# Inches          0.066990
# Price_euros     1.000000
# Ram_GB          0.740106
# Weight_kg       0.212192
# Touch_screen    0.188631
# IPS             0.250358
# y_resolution    0.548111
# x_resolution    0.072208
# PPI             0.342449
# Name: Price_euros, dtype: float64

# %%
df.drop(["ScreenResolution"],axis = 1, inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu               Memory  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz            128GB SSD
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz  128GB Flash Storage
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz            256GB SSD
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz            512GB SSD
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz            256GB SSD
#
#                             Gpu  OpSys  Price_euros  Ram_GB  Weight_kg  \
# 0  Intel Iris Plus Graphics 640  macOS      1339.69       8       1.37
# 1        Intel HD Graphics 6000  macOS       898.94       8       1.34
# 2         Intel HD Graphics 620  No OS       575.00       8       1.86
# 3            AMD Radeon Pro 455  macOS      2537.45      16       1.83
# 4  Intel Iris Plus Graphics 650  macOS      1803.60       8       1.37
#
#    Touch_screen  IPS  y_resolution  x_resolution         PPI
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz     190
# Intel Core i7 7700HQ 2.8GHz    146
# Intel Core i7 7500U 2.7GHz     132
# Intel Core i7 8550U 1.8GHz      73
# Intel Core i5 8250U 1.6GHz      72
#                               ...
# Intel Core M M3-6Y30 0.9GHz      1
# AMD A9-Series 9420 2.9GHz        1
# Intel Core i5 2.9GHz             1
# AMD A6-Series 7310 2GHz          1
# AMD A9-Series 9410 2.9GHz        1
# Name: Cpu, Length: 118, dtype: int64

# %% [markdown]
# ### all intel processor

# %%
df[df['Cpu'].str.contains("Intel")]
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1269    Asus            Notebook    15.6
# 1270  Lenovo  2 in 1 Convertible    14.0
# 1271  Lenovo  2 in 1 Convertible    13.3
# 1272  Lenovo            Notebook    14.0
# 1273      HP            Notebook    15.6
#
#                                        Cpu               Memory  \
# 0                     Intel Core i5 2.3GHz            128GB SSD
# 1                     Intel Core i5 1.8GHz  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz            256GB SSD
# 3                     Intel Core i7 2.7GHz            512GB SSD
# 4                     Intel Core i5 3.1GHz            256GB SSD
# ...                                    ...                  ...
# ...

# %% [markdown]
# ### all AMD processor

# %%
df[df['Cpu'].str.contains("AMD")]
# Out:
#      Company   TypeName  Inches                              Cpu  \
# 5       Acer   Notebook    15.6          AMD A9-Series 9420 3GHz
# 22        HP   Notebook    15.6     AMD E-Series E2-9000e 1.5GHz
# 31      Asus   Notebook    14.0      AMD E-Series E2-6110 1.5GHz
# 32        HP   Notebook    17.3        AMD A6-Series 9220 2.5GHz
# 47      Asus     Gaming    17.3              AMD Ryzen 1700 3GHz
# 52        HP   Notebook    15.6        AMD A6-Series 9220 2.5GHz
# 83    Lenovo   Notebook    15.6        AMD A6-Series 9220 2.5GHz
# 84      Acer   Notebook    15.6          AMD A9-Series 9420 3GHz
# 90      Asus     Gaming    15.6                AMD FX 9830P 3GHz
# 101       HP   Notebook    15.6     AMD E-Series E2-9000e 1.5GHz
# 124     Acer   Notebook    15.6          AMD A9-Series 9420 3GHz
# 127     Asus   Notebook    14.0         AMD E-Series 6110 1.5GHz
# 144       HP   Notebook    15.6        AMD A6-Series 9220 2.5GHz
# ...

# %%
df[df['Cpu'].str.contains("AMD")].shape
# Out:
# (60, 15)

# %% [markdown]
# ### without Intel or Amd processor

# %%
df[df["Cpu"].apply(lambda x: "Intel" not in x and "AMD" not in x)]
# Out:
#       Company            TypeName  Inches                            Cpu  \
# 1191  Samsung  2 in 1 Convertible    12.3  Samsung Cortex A72&A53 2.0GHz
#
#                   Memory                Gpu      OpSys  Price_euros  Ram_GB  \
# 1191  32GB Flash Storage  ARM Mali T860 MP4  Chrome OS        659.0       4
#
#       Weight_kg  Touch_screen  IPS  y_resolution  x_resolution         PPI
# 1191       1.15             1    1          1600          2400  234.507401

# %%
df[df['Cpu'].str.contains("Intel")]['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz     190
# Intel Core i7 7700HQ 2.8GHz    146
# Intel Core i7 7500U 2.7GHz     132
# Intel Core i7 8550U 1.8GHz      73
# Intel Core i5 8250U 1.6GHz      72
#                               ...
# Intel Core i3 6100U 2.1GHz       1
# Intel Atom x5-Z8300 1.44GHz      1
# Intel Core M M3-6Y30 0.9GHz      1
# Intel Atom Z8350 1.92GHz         1
# Intel Core M 6Y30 0.9GHz         1
# Name: Cpu, Length: 90, dtype: int64

# %%
df[df['Cpu'].str.contains("AMD")]['Cpu'].value_counts()
# Out:
# AMD A9-Series 9420 3GHz            11
# AMD A6-Series 9220 2.5GHz           7
# AMD A12-Series 9720P 3.6GHz         5
# AMD A8-Series 7410 2.2GHz           4
# AMD Ryzen 1700 3GHz                 3
# AMD A10-Series 9600P 2.4GHz         2
# AMD A9-Series A9-9420 3GHz          2
# AMD E-Series 7110 1.8GHz            2
# AMD A10-Series 9620P 2.5GHz         2
# AMD E-Series E2-9000e 1.5GHz        2
# AMD A12-Series 9720P 2.7GHz         2
# AMD A6-Series A6-9220 2.5GHz        2
# AMD A10-Series A10-9620P 2.5GHz     2
# AMD E-Series 9000e 1.5GHz           1
# AMD A6-Series 9220 2.9GHz           1
# AMD Ryzen 1600 3.2GHz               1
# AMD E-Series 6110 1.5GHz            1
# AMD FX 9830P 3GHz                   1
# AMD E-Series E2-6110 1.5GHz         1
# AMD E-Series E2-9000 2.2GHz         1
# AMD A9-Series 9420 2.9GHz           1
# AMD A6-Series 7310 2GHz             1
# AMD A12-Series 9700P 2.5GHz         1
# AMD A4-Series 7210 2.2GHz           1
# AMD FX 8800P 2.1GHz                 1
# ...

# %%
df['Cpu_brand']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
df['Cpu_brand'].value_counts()
# Out:
# Intel Core i7               515
# Intel Core i5               423
# Intel Core i3               134
# Intel Celeron Dual           69
# Intel Pentium Quad           27
# Intel Core M                 17
# AMD A9-Series 9420           12
# AMD A6-Series 9220            8
# Intel Celeron Quad            8
# AMD A12-Series 9720P          7
# Intel Atom x5-Z8350           5
# Intel Atom x5-Z8550           4
# AMD A8-Series 7410            4
# Intel Pentium Dual            3
# AMD Ryzen 1700                3
# Intel Atom X5-Z8350           2
# Intel Xeon E3-1535M           2
# AMD A9-Series A9-9420         2
# AMD E-Series 7110             2
# AMD A10-Series 9620P          2
# AMD A10-Series 9600P          2
# AMD A6-Series A6-9220         2
# Intel Xeon E3-1505M           2
# AMD E-Series E2-9000e         2
# AMD A10-Series A10-9620P      2
# Intel Atom x5-Z8300           1
# AMD E-Series 9000             1
# Samsung Cortex A72&A53        1
# AMD FX 8800P                  1
# ...

# %%
# create a function to minimize cpu name 
def cpu_name(x):
    if x == "Intel Core i3" or x == "Intel Core i5" or x == "Intel Core i7":
        return x
    else:
        if x.split()[0] == "Intel":
            return "Intel other processor"
        elif x.split()[0] == "AMD":
            return "AMD Processor"
        elif x.split()[0] == "Samsung":
            return "Samsung processor"

# %%
df['Cpu_name']=df['Cpu_brand'].apply(cpu_name)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu               Memory  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz            128GB SSD
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz  128GB Flash Storage
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz            256GB SSD
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz            512GB SSD
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz            256GB SSD
#
#                             Gpu  OpSys  Price_euros  Ram_GB  Weight_kg  \
# 0  Intel Iris Plus Graphics 640  macOS      1339.69       8       1.37
# 1        Intel HD Graphics 6000  macOS       898.94       8       1.34
# 2         Intel HD Graphics 620  No OS       575.00       8       1.86
# 3            AMD Radeon Pro 455  macOS      2537.45      16       1.83
# 4  Intel Iris Plus Graphics 650  macOS      1803.60       8       1.37
#
# ...

# %%
df['Cpu_name'].value_counts()
# Out:
# Intel Core i7            515
# Intel Core i5            423
# Intel other processor    141
# Intel Core i3            134
# AMD Processor             60
# Samsung processor          1
# Name: Cpu_name, dtype: int64

# %%
df.sample(7)
# Out:
#     Company   TypeName  Inches                          Cpu  \
# 632  Lenovo   Notebook    15.6   Intel Core i5 8250U 1.6GHz
# 972    Dell     Gaming    17.3  Intel Core i7 6700HQ 2.6GHz
# 309      HP   Notebook    15.6     Intel Core i3 6006U 2GHz
# 186    Dell   Notebook    15.6  Intel Core i7 7700HQ 2.8GHz
# 52       HP   Notebook    15.6    AMD A6-Series 9220 2.5GHz
# 3     Apple  Ultrabook    15.4         Intel Core i7 2.7GHz
# 298  Lenovo   Notebook    15.6  AMD A10-Series 9600P 2.4GHz
#
#                    Memory                      Gpu       OpSys  Price_euros  \
# 632             256GB SSD   Intel UHD Graphics 620  Windows 10       829.00
# 972  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1070  Windows 10      2800.00
# 309               1TB HDD    Intel HD Graphics 520  Windows 10       469.00
# 186             512GB SSD  Nvidia GeForce GTX 1050  Windows 10      2397.00
# 52              256GB SSD   AMD Radeon R4 Graphics  Windows 10       398.49
# ...

# %%
sns.barplot(x=df['Cpu_name'],y=df['Price_euros'])
plt.xticks(rotation = 90);

# %%
df.drop(['Cpu_brand','Cpu'],axis = 1, inplace = True)

# %%
sns.countplot(df['Ram_GB']);
# Out:
# E:\bul_reg\ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.barplot(x=df['Ram_GB'],y=df['Price_euros'])
plt.xticks(rotation = 90);

# %%
df.head(4)
# Out:
#   Company   TypeName  Inches               Memory  \
# 0   Apple  Ultrabook    13.3            128GB SSD
# 1   Apple  Ultrabook    13.3  128GB Flash Storage
# 2      HP   Notebook    15.6            256GB SSD
# 3   Apple  Ultrabook    15.4            512GB SSD
#
#                             Gpu  OpSys  Price_euros  Ram_GB  Weight_kg  \
# 0  Intel Iris Plus Graphics 640  macOS      1339.69       8       1.37
# 1        Intel HD Graphics 6000  macOS       898.94       8       1.34
# 2         Intel HD Graphics 620  No OS       575.00       8       1.86
# 3            AMD Radeon Pro 455  macOS      2537.45      16       1.83
#
#    Touch_screen  IPS  y_resolution  x_resolution         PPI       Cpu_name
# 0             0    1          1600          2560  226.983002  Intel Core i5
# 1             0    0           900          1440  127.677940  Intel Core i5
# 2             0    0          1080          1920  141.212006  Intel Core i5
# ...

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          215
# 500GB HDD                        123
# 512GB SSD                        114
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         74
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                36
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 64GB Flash Storage                13
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 1.0TB Hybrid                       7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df.drop(['Inches','y_resolution','x_resolution'],axis = 1, inplace = True)

# %%
new_df=df[['Memory','Price_euros']]
new_df
# Out:
#                    Memory  Price_euros
# 0               128GB SSD      1339.69
# 1     128GB Flash Storage       898.94
# 2               256GB SSD       575.00
# 3               512GB SSD      2537.45
# 4               256GB SSD      1803.60
# ...                   ...          ...
# 1269            500GB HDD       720.32
# 1270            128GB SSD       638.00
# 1271            512GB SSD      1499.00
# 1272   64GB Flash Storage       229.00
# 1273              1TB HDD       764.00
#
# [1274 rows x 2 columns]

# %%
new_df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          215
# 500GB HDD                        123
# 512GB SSD                        114
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         74
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                36
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 64GB Flash Storage                13
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 1.0TB Hybrid                       7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
new_df['Memory1']=new_df['Memory'].str.replace('\.0','',regex = True)
new_df['Memory1']=new_df['Memory1'].str.replace('GB',"")
new_df['Memory1']=new_df['Memory1'].str.replace('TB',"000")
new_df1=new_df['Memory1'].str.split("+",expand = True)
# Out:
# E:\bul_reg\ml\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
new_df['Memory1'].value_counts()
# Out:
# 256 SSD                         412
# 1000 HDD                        216
# 500 HDD                         123
# 512 SSD                         114
# 128 SSD +  1000 HDD              94
# 128 SSD                          74
# 256 SSD +  1000 HDD              73
# 32 Flash Storage                 36
# 2000 HDD                         16
# 512 SSD +  1000 HDD              14
# 1000 SSD                         14
# 64 Flash Storage                 13
# 256 SSD +  2000 HDD              10
# 256 Flash Storage                 8
# 16 Flash Storage                  7
# 1000 Hybrid                       7
# 32 SSD                            6
# 180 SSD                           5
# 128 Flash Storage                 4
# 512 SSD +  2000 HDD               3
# 16 SSD                            3
# 512 Flash Storage                 2
# 1000 SSD +  1000 HDD              2
# 256 SSD +  500 HDD                2
# 128 SSD +  2000 HDD               2
# 256 SSD +  256 SSD                2
# ...

# %%
new_df1.sample(5)
# Out:
#                      0     1
# 1273          1000 HDD  None
# 161            256 SSD  None
# 831            512 SSD  None
# 95             256 SSD  None
# 515   32 Flash Storage  None

# %%
new_df['first']=new_df1[0]
new_df
# Out:
# E:\bul_reg\ml\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#                    Memory  Price_euros            Memory1              first
# 0               128GB SSD      1339.69            128 SSD            128 SSD
# 1     128GB Flash Storage       898.94  128 Flash Storage  128 Flash Storage
# 2               256GB SSD       575.00            256 SSD            256 SSD
# 3               512GB SSD      2537.45            512 SSD            512 SSD
# 4               256GB SSD      1803.60            256 SSD            256 SSD
# ...                   ...          ...                ...                ...
# ...

# %%
new_df['first']=new_df['first'].str.strip()
new_df.head()
# Out:
# E:\bul_reg\ml\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#                 Memory  Price_euros            Memory1              first
# 0            128GB SSD      1339.69            128 SSD            128 SSD
# 1  128GB Flash Storage       898.94  128 Flash Storage  128 Flash Storage
# 2            256GB SSD       575.00            256 SSD            256 SSD
# 3            512GB SSD      2537.45            512 SSD            512 SSD
# 4            256GB SSD      1803.60            256 SSD            256 SSD

# %%
new_df['second']=new_df1[1]
new_df
# Out:
# E:\bul_reg\ml\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#                    Memory  Price_euros            Memory1              first  \
# 0               128GB SSD      1339.69            128 SSD            128 SSD
# 1     128GB Flash Storage       898.94  128 Flash Storage  128 Flash Storage
# 2               256GB SSD       575.00            256 SSD            256 SSD
# 3               512GB SSD      2537.45            512 SSD            512 SSD
# 4               256GB SSD      1803.60            256 SSD            256 SSD
# ...                   ...          ...                ...                ...
# ...

# %%
new_df['second'].value_counts(dropna = False)
# Out:
# NaN              1066
#   1000 HDD        185
#   2000 HDD         15
#   256 SSD           3
#   500 HDD           2
#   1000 Hybrid       2
#   512 SSD           1
# Name: second, dtype: int64

# %%
new_df['layer1HDD']=new_df['first'].apply(lambda x:1 if "HDD" in x else 0)
new_df['layer1SSD']=new_df['first'].apply(lambda x:1 if "SSD" in x else 0)
new_df['layer1Hybrid']=new_df['first'].apply(lambda x:1 if "Hybrid" in x else 0)
new_df['layer1Flash_Storage']=new_df['first'].apply(lambda x:1 if "Flash Storage" in x else 0)
# Out:
# E:\bul_reg\ml\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
new_df.sample(5)
# Out:
#          Memory  Price_euros   Memory1     first second  layer1HDD  layer1SSD  \
# 770   256GB SSD      1181.27   256 SSD   256 SSD   None          0          1
# 529   256GB SSD      1377.00   256 SSD   256 SSD   None          0          1
# 285     1TB HDD       659.00  1000 HDD  1000 HDD   None          1          0
# 1096    1TB HDD       638.80  1000 HDD  1000 HDD   None          1          0
# 700     1TB HDD       819.00  1000 HDD  1000 HDD   None          1          0
#
#       layer1Hybrid  layer1Flash_Storage
# 770              0                    0
# 529              0                    0
# 285              0                    0
# 1096             0                    0
# 700              0                    0

# %%
new_df['first']=new_df['first'].str.replace(r'\D','')
new_df.sample(4)
# Out:
# <ipython-input-76-6a2b0db076a7>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   new_df['first']=new_df['first'].str.replace(r'\D','')
# E:\bul_reg\ml\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#                     Memory  Price_euros              Memory1 first  \
# 722              256GB SSD       1499.0              256 SSD   256
# 1068  256GB SSD +  1TB HDD       1329.0  256 SSD +  1000 HDD   256
# 897                1TB HDD        900.0             1000 HDD  1000
# 1029             256GB SSD       1080.0              256 SSD   256
#
# ...

# %%
new_df['second'].fillna("0",inplace = True)
new_df.sample(4)
# Out:
# E:\bul_reg\ml\lib\site-packages\pandas\core\generic.py:6383: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
#                     Memory  Price_euros              Memory1 first  \
# 604                1TB HDD       465.00             1000 HDD  1000
# 1093             256GB SSD       818.35              256 SSD   256
# 280   128GB SSD +  1TB HDD       859.00  128 SSD +  1000 HDD   128
# 1020               1TB HDD       795.99             1000 HDD  1000
#
#           second  layer1HDD  layer1SSD  layer1Hybrid  layer1Flash_Storage
# 604            0          1          0             0                    0
# 1093           0          0          1             0                    0
# 280     1000 HDD          0          1             0                    0
# ...

# %%
new_df['layer2HDD']=new_df['second'].apply(lambda x:1 if "HDD" in x else 0)
new_df['layer2SSD']=new_df['second'].apply(lambda x:1 if "SSD" in x else 0)
new_df['layer2Hybrid']=new_df['second'].apply(lambda x:1 if "Hybrid" in x else 0)
new_df['layer2Flash_Storage']=new_df['second'].apply(lambda x:1 if "Flash Storage" in x else 0)
# Out:
# E:\bul_reg\ml\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
new_df.sample(6)
# Out:
#          Memory  Price_euros   Memory1 first second  layer1HDD  layer1SSD  \
# 1006  256GB SSD      1205.00   256 SSD   256      0          0          1
# 410   512GB SSD      1925.00   512 SSD   512      0          0          1
# 357     1TB HDD       999.00  1000 HDD  1000      0          1          0
# 668   256GB SSD      1258.00   256 SSD   256      0          0          1
# 1050  256GB SSD      2620.00   256 SSD   256      0          0          1
# 289     1TB HDD       659.01  1000 HDD  1000      0          1          0
#
#       layer1Hybrid  layer1Flash_Storage  layer2HDD  layer2SSD  layer2Hybrid  \
# 1006             0                    0          0          0             0
# 410              0                    0          0          0             0
# 357              0                    0          0          0             0
# 668              0                    0          0          0             0
# ...

# %%
new_df['second']=new_df['second'].str.replace(r'\D','')
new_df.sample(4)
# Out:
# <ipython-input-80-117ef6db6958>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   new_df['second']=new_df['second'].str.replace(r'\D','')
#                    Memory  Price_euros              Memory1 first second  \
# 0               128GB SSD      1339.69              128 SSD   128      0
# 193             256GB SSD       698.00              256 SSD   256      0
# 335             256GB SSD      1268.00              256 SSD   256      0
# 790  128GB SSD +  1TB HDD      1339.00  128 SSD +  1000 HDD   128   1000
#
#      layer1HDD  layer1SSD  layer1Hybrid  layer1Flash_Storage  layer2HDD  \
# 0            0          1             0                    0          0
# 193          0          1             0                    0          0
# 335          0          1             0                    0          0
# 790          0          1             0                    0          1
#
#      layer2SSD  layer2Hybrid  layer2Flash_Storage
# ...

# %%
new_df['first']=new_df['first'].astype('int32')
new_df['second']=new_df['second'].astype('int32')

# %%
df['HDD']=(new_df['first']*new_df['layer1HDD']+new_df['second']*new_df['layer2HDD'])
df['SSD']=(new_df['first']*new_df['layer1SSD']+new_df['second']*new_df['layer2SSD'])
df['Hybrid']=(new_df['first']*new_df['layer1Hybrid']+new_df['second']*new_df['layer2Hybrid'])
df['Flash_storage']=(new_df['first']*new_df['layer1Flash_Storage']+new_df['second']*new_df['layer2Flash_Storage'])

# %%
df.head()
# Out:
#   Company   TypeName               Memory                           Gpu  \
# 0   Apple  Ultrabook            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Price_euros  Ram_GB  Weight_kg  Touch_screen  IPS         PPI  \
# 0  macOS      1339.69       8       1.37             0    1  226.983002
# 1  macOS       898.94       8       1.34             0    0  127.677940
# 2  No OS       575.00       8       1.86             0    0  141.212006
# 3  macOS      2537.45      16       1.83             0    1  220.534622
# 4  macOS      1803.60       8       1.37             0    1  226.983002
#
#         Cpu_name  HDD  SSD  Hybrid  Flash_storage
# ...

# %%
df.sample(6)
# Out:
#      Company   TypeName                Memory                      Gpu  \
# 1091      HP   Notebook               1TB HDD    Intel HD Graphics 520
# 946     Dell  Ultrabook             256GB SSD        Intel HD Graphics
# 940       HP     Gaming  128GB SSD +  1TB HDD  Nvidia GeForce GTX 965M
# 617       HP  Ultrabook             512GB SSD    Intel HD Graphics 620
# 134       HP   Notebook               1TB HDD    Intel HD Graphics 620
# 669     Acer   Notebook             128GB SSD    Intel HD Graphics 520
#
#            OpSys  Price_euros  Ram_GB  Weight_kg  Touch_screen  IPS  \
# 1091       No OS       345.99       4       1.86             0    0
# 946   Windows 10      1472.20       8       1.36             1    0
# 940   Windows 10      1399.00       8       2.75             0    1
# 617   Windows 10      1389.00       8       1.84             0    0
# 134   Windows 10       598.00       8       2.05             0    0
# ...

# %%
df.drop(['Memory'],axis =1, inplace = True)

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      279
# Intel HD Graphics 520      181
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['Gpu_brand']=df['Gpu'].apply(lambda x:x.split()[0])

# %%
df['Gpu_brand'].value_counts()
# Out:
# Intel     703
# Nvidia    396
# AMD       174
# ARM         1
# Name: Gpu_brand, dtype: int64

# %%
df=df[df['Gpu_brand']!="ARM"]

# %%
df['Gpu_brand'].value_counts()
# Out:
# Intel     703
# Nvidia    396
# AMD       174
# Name: Gpu_brand, dtype: int64

# %%
df.drop(['Gpu'],axis = 1, inplace =True)

# %%
sns.barplot(x=df['Gpu_brand'],y=df['Price_euros'])
plt.xticks(rotation = 90);

# %%
sns.boxplot(df['Price_euros'],df['Gpu_brand']);
# Out:
# E:\bul_reg\ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1047
# No OS             66
# Linux             58
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
df[df['OpSys']=="Android"]
# Out:
#      Company            TypeName    OpSys  Price_euros  Ram_GB  Weight_kg  \
# 50    Lenovo  2 in 1 Convertible  Android        319.0       4       0.69
# 1114  Lenovo  2 in 1 Convertible  Android        549.0       4       0.69
#
#       Touch_screen  IPS         PPI               Cpu_name  HDD  SSD  Hybrid  \
# 50               1    1  224.173813  Intel other processor    0    0       0
# 1114             1    1  224.173813  Intel other processor    0    0       0
#
#       Flash_storage Gpu_brand
# 50               64     Intel
# 1114             64     Intel

# %%
sns.barplot(x=df['OpSys'],y=df['Price_euros'])
plt.xticks(rotation = 90);

# %%
def os(x):
    if x == "Windows 10" or x == "Windows 10 S" or x == "Windows 7":
        return "windows"
    elif x == "Mac OS X" or x == "macOS":
        return "Mac"
    else:
        return "others"

# %%
df['OS']=df['OpSys'].apply(os)

# %%
df['OS'].value_counts()
# Out:
# windows    1100
# others      152
# Mac          21
# Name: OS, dtype: int64

# %%
sns.barplot(x=df['OS'],y=df['Price_euros'])
plt.xticks(rotation = 90);

# %%
df.drop(['OpSys'],axis =1,inplace = True)

# %%
sns.histplot(df['Weight_kg'])
# Out:
# <AxesSubplot:xlabel='Weight_kg', ylabel='Count'>

# %%
sns.scatterplot(df['Weight_kg'],df['Price_euros']);
# Out:
# E:\bul_reg\ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(),annot= True)
# Out:
# <AxesSubplot:>

# %%
df.drop(['Hybrid','Flash_storage'],axis =1,inplace =True)

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Price_euros', 'Ram_GB', 'Weight_kg',
#        'Touch_screen', 'IPS', 'PPI', 'Cpu_name', 'HDD', 'SSD', 'Gpu_brand',
#        'OS'],
#       dtype='object')

# %%
sns.histplot(np.log(df.Price_euros));

# %%
x = df.drop(['Price_euros'],axis=1)
y = np.log(df['Price_euros'])

# %%
x.columns
# Out:
# Index(['Company', 'TypeName', 'Ram_GB', 'Weight_kg', 'Touch_screen', 'IPS',
#        'PPI', 'Cpu_name', 'HDD', 'SSD', 'Gpu_brand', 'OS'],
#       dtype='object')

# %%
sns.histplot(y)
# Out:
# <AxesSubplot:xlabel='Price_euros', ylabel='Count'>

# %%
sns.boxplot(y,df['Gpu_brand']);
# Out:
# E:\bul_reg\ml\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.15,random_state=69)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score, mean_absolute_error

# %%
x_train
# Out:
#      Company            TypeName  Ram_GB  Weight_kg  Touch_screen  IPS  \
# 640   Lenovo              Gaming       8       2.50             0    1
# 124     Acer            Notebook       4       2.10             0    0
# 1245    Asus              Gaming      16       2.50             0    1
# 992   Lenovo            Notebook       4       1.90             0    0
# 1124    Asus            Notebook       4       2.00             0    0
# ...      ...                 ...     ...        ...           ...  ...
# 404      MSI              Gaming      16       2.80             0    0
# 439     Asus            Notebook       4       2.00             0    0
# 619     Acer  2 in 1 Convertible       4       1.25             1    1
# 1228  Lenovo              Gaming      16       2.60             1    1
# 1078  Lenovo            Notebook       4       2.10             0    0
#
#              PPI               Cpu_name   HDD  SSD Gpu_brand       OS
# ...

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %% [markdown]
# ### 1. Linear Regression

# %%
step1 = ColumnTransformer(transformers =[('col_tf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])],
                         remainder = 'passthrough')
step2=LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ("step2",step2)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print("r^2:", r2_score(y_test,y_pred))
print("MAE:", mean_absolute_error(y_test,y_pred))
# Out:
# r^2: 0.7984360630832041
# MAE: 0.21081336397756784

# %% [markdown]
# ## 2. Ridge Regression

# %%
step1 = ColumnTransformer(transformers =[('col_tf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])],
                         remainder = "passthrough")
step2 = Ridge()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print("r^2:", r2_score(y_test,y_pred))
print("MAE:", mean_absolute_error(y_test,y_pred))
# Out:
# r^2: 0.7970305859174476
# MAE: 0.2123073146856345

# %% [markdown]
# ## 3. Lasso Regression

# %%
step1 = ColumnTransformer(transformers = [('col_tf',OneHotEncoder(sparse = False,drop = 'first'),[0,1,7,10,11])],
                         remainder = 'passthrough')

step2 = Lasso(alpha = 0.003)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print("r^2:", r2_score(y_test,y_pred))
print("MAE:", mean_absolute_error(y_test,y_pred))
# Out:
# r^2: 0.7713917369672378
# MAE: 0.22296012155258468

# %% [markdown]
# ## 4. KNN

# %%
step1 = ColumnTransformer(transformers = [('col_tf',OneHotEncoder(sparse = False,drop='first'),[0,1,7,10,11])],
                         remainder = 'passthrough')

step2 = KNeighborsRegressor(n_neighbors=2)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print("r^2:", r2_score(y_test,y_pred))
print("MAE:", mean_absolute_error(y_test,y_pred))
# Out:
# r^2: 0.7553633623698726
# MAE: 0.21541036653429552

# %% [markdown]
# ## 5. SVM

# %%
step1 = ColumnTransformer(transformers = [('col_tf',OneHotEncoder(sparse = False,drop='first'),[0,1,7,10,11])],
                         remainder = 'passthrough')
step2 = SVR(kernel = 'rbf',C = 10000, epsilon = 0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print("r^2:", r2_score(y_test,y_pred))
print("MAE:", mean_absolute_error(y_test,y_pred))
# Out:
# r^2: 0.8230810037850289
# MAE: 0.195106897177373

# %% [markdown]
# ## 6. Decision Tree

# %%
step1 = ColumnTransformer(transformers = [('col_tf',OneHotEncoder(sparse = False,drop='first'),[0,1,7,10,11])],
                         remainder = 'passthrough')
step2 = DecisionTreeRegressor(max_depth = 10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print("r^2:", r2_score(y_test,y_pred))
print("MAE:", mean_absolute_error(y_test,y_pred))
# Out:
# r^2: 0.7928232388086828
# MAE: 0.20482868151701786

# %% [markdown]
# ## 7. Random Forest

# %%
step1 = ColumnTransformer(transformers = [('col_tf',OneHotEncoder(sparse = False,drop='first'),[0,1,7,10,11])],
                         remainder = 'passthrough')
step2 = RandomForestRegressor(max_depth = 15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print("r^2:", r2_score(y_test,y_pred))
print("MAE:", mean_absolute_error(y_test,y_pred))
# Out:
# r^2: 0.8736980111251971
# MAE: 0.16463500859271657

# %% [markdown]
# ## 8. AdaBoost

# %%
step1 = ColumnTransformer(transformers = [('col_tf',OneHotEncoder(sparse = False,drop='first'),[0,1,7,10,11])],
                         remainder = 'passthrough')
step2 = AdaBoostRegressor(n_estimators = 220)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print("r^2:", r2_score(y_test,y_pred))
print("MAE:", mean_absolute_error(y_test,y_pred))
# Out:
# r^2: 0.7887628247316564
# MAE: 0.21607817504274826

# %% [markdown]
# ## 9. GradientBoost

# %%
step1 = ColumnTransformer(transformers = [('col_tf',OneHotEncoder(sparse = False,drop='first'),[0,1,7,10,11])],
                         remainder = 'passthrough')
step2 = GradientBoostingRegressor(n_estimators = 300)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print("r^2:", r2_score(y_test,y_pred))
print("MAE:", mean_absolute_error(y_test,y_pred))
# Out:
# r^2: 0.8878058623005833
# MAE: 0.15562138735213435

# %% [markdown]
# ## 10. XGBoost

# %%
step1 = ColumnTransformer(transformers = [('col_tf',OneHotEncoder(sparse = False,drop='first'),[0,1,7,10,11])],
                         remainder = 'passthrough')
step2 = XGBRegressor(max_depth = 500, learning_rate = 0.07)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(x_train,y_train)

y_pred = pipe.predict(x_test)

print("r^2:", r2_score(y_test,y_pred))
print("MAE:", mean_absolute_error(y_test,y_pred))
# Out:
# r^2: 0.881103879909697
# MAE: 0.15805216036862024

# %% [markdown]
# #### Among all the models model 9 gives us the best score. So using this algorithm we can build a better model.
